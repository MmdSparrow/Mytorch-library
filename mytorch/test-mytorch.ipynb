# %%
# import sys
# import os
# sys.path.append(os.path.abspath(os.getcwd()))
from mytorch import Tensor
from mytorch.layer import Conv2d


a=Tensor([[[[1,3,1],[3,1,2]], [[1,3,1],[3,1,2]]], [[[2,2,2],[2,2,2]], [[1,3,1],[3,1,2]]]])
conv_layer = Conv2d(in_channels=2, out_channels=1, kernel_size=(2,2))

# Perform the convolution operation
output = conv_layer(a)

print(output)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 import os
#       3 sys.path.append(os.path.abspath(os.getcwd()))
# ----> 4 from mytorch import Tensor
#       5 from mytorch.layer import Conv2d
#       8 a=Tensor([[[[1,3,1],[3,1,2]], [[1,3,1],[3,1,2]]], [[[2,2,2],[2,2,2]], [[1,3,1],[3,1,2]]]])
#
# ModuleNotFoundError: No module named 'mytorch'
